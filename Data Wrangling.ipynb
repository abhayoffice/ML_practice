# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\abhay.bhandari\Jupyter files\Practice files\New folder\endangeredLang.csv")

# %%
data.head()
# Out:
#      ID Name in English  Name in French      Name in Spanish  \
# 0  1022   South Italian  italien du sud  napolitano-calabrés
# 1  1023        Sicilian        sicilien            siciliano
# 2   383       Low Saxon       bas-saxon           bajo sajón
# 3   335      Belarusian      biélorusse           bielorruso
# 4   382         Lombard         lombard             lombardo
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#           Country codes alpha 3  \
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE
#
# ...

# %%
data.describe()
# Out:
#                 ID  Number of speakers     Latitude    Longitude
# count  2722.000000        2.539000e+03  2719.000000  2719.000000
# mean   1362.501102        5.365890e+04    16.247853    22.266012
# std     785.919949        3.114620e+05    23.241828    92.611293
# min       2.000000        0.000000e+00   -55.002800  -174.197800
# 25%     682.250000        5.000000e+01    -2.705000   -69.180850
# 50%    1362.500000        8.000000e+02    15.658700    30.591400
# 75%    2042.750000        6.872000e+03    34.214050   102.366000
# max    2724.000000        7.500000e+06    77.481500   179.187000

# %%
data.sort_values(by = "Number of speakers", ascending = False).head()
# Out:
#      ID Name in English  Name in French      Name in Spanish  \
# 0  1022   South Italian  italien du sud  napolitano-calabrés
# 1  1023        Sicilian        sicilien            siciliano
# 2   383       Low Saxon       bas-saxon           bajo sajón
# 3   335      Belarusian      biélorusse           bielorruso
# 4   382         Lombard         lombard             lombardo
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#           Country codes alpha 3  \
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE
#
# ...

# %%
data.groupby(['Countries','Degree of endangerment']).count()

# val.sort_values(by = 'Number of speakers').head()
# Out:
#                                                                            ID  \
# Countries                                          Degree of endangerment
# Afghanistan                                        Critically endangered    2
#                                                    Definitely endangered    5
#                                                    Severely endangered      4
#                                                    Vulnerable               1
# Albania, Algeria, Bosnia and Herzegovina, Bulga... Severely endangered      1
# ...                                                                        ..
# Viet Nam                                           Severely endangered      2
#                                                    Vulnerable               4
# Western Sahara                                     Critically endangered    1
# Yemen                                              Definitely endangered    1
# ...

# %%
from pandas.core.groupby import DataFrameGroupBy

India_Lang = data[data["Countries"] == "India"]
India_Lang = India_Lang.groupby[["Name in English", "Number of speakers"]]
# India_df = India_Lang.to
# # India_df.to_csv("IndiaLang.csv")
# Out:
#       ID Name in English Name in French Name in Spanish Countries  \
# 7   1586           Gondi          gondi           gondí     India
# 16  1591   Kurux (India)   kurux (Inde)   kuruj (India)     India
# 18  1585            Tulu           tulu            tulú     India
# 19  1556          Kangdi         Kangdi          kangdi     India
# 26  1227         Meithei         meitei           mitei     India
#
#    Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 7                    IND            gon             Vulnerable
# 16                   IND            kru             Vulnerable
# 18                   IND            tcy             Vulnerable
# 19                   IND            xnr  Definitely endangered
# 26                   IND            mni             Vulnerable
#
#                                       Alternate names Name in the language  \
# 7   Gondi; Gaudi; Gondiva; Gondwadi; Goondile; Gou...                  NaN
# ...
